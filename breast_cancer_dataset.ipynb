# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-ec70c1cf-1eca-475e-9e1a-a90d7fd52e6e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ec70c1cf-1eca-475e-9e1a-a90d7fd52e6e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Replace 'your_file.csv' with your actual filename
df = pd.read_csv('Breast_cancer_dataset.csv')

# Preview first few rows
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Task
# Analyze the data in the provided CSV file "data.csv" using Python. The analysis should include: importing necessary libraries (Pandas, NumPy, Matplotlib, Seaborn), loading and previewing the dataset, checking for and handling missing values, describing the data with summary statistics, creating various visualizations (bar charts, pie charts, line charts, correlation heatmap, histograms), analyzing patterns, trends, and outliers, and writing 5 key insights from the data. The output should be visually appealing and well-structured.

# %% [markdown]
# ## Load and preview data
#
# ### Subtask:
# Load the dataset using pandas and display the first few rows and column information.

# %% [markdown]
# **Reasoning**:
# Load the dataset, display the head and info of the dataframe to fulfill the subtask.

# %%
# Display the first 5 rows
display(df.head())

# Display column names and data types
df.info()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# ## Handle missing values
#
# ### Subtask:
# Check for missing values and decide on an appropriate strategy to handle them (e.g., imputation, removal).

# %% [markdown]
# **Reasoning**:
# Check for missing values in each column and then drop the column with all missing values.

# %%
# Check for missing values in each column
missing_values = df.isnull().sum()

# Display the sum of missing values for each column
print("Missing values per column:")
print(missing_values)

# Drop the column 'Unnamed: 32' as it contains all missing values
df = df.drop('Unnamed: 32', axis=1)

# Verify that the column 'Unnamed: 32' has been removed
df.info()
# Out:
# Missing values per column:
# id                           0
# diagnosis                    0
# radius_mean                  0
# texture_mean                 0
# perimeter_mean               0
# area_mean                    0
# smoothness_mean              0
# compactness_mean             0
# concavity_mean               0
# concave points_mean          0
# symmetry_mean                0
# fractal_dimension_mean       0
# radius_se                    0
# texture_se                   0
# perimeter_se                 0
# area_se                      0
# smoothness_se                0
# compactness_se               0
# concavity_se                 0
# concave points_se            0
# symmetry_se                  0
# fractal_dimension_se         0
# radius_worst                 0
# texture_worst                0
# perimeter_worst              0
# area_worst                   0
# smoothness_worst             0
# compactness_worst            0
# concavity_worst              0
# ...

# %% [markdown]
# ## Describe data
#
# ### Subtask:
# Generate summary statistics for numerical and categorical columns.

# %% [markdown]
# **Reasoning**:
# Generate descriptive statistics for both numerical and categorical columns and print the results.

# %%
# Generate descriptive statistics for numerical columns
numerical_summary = df.describe()
print("Descriptive statistics for numerical columns:")
display(numerical_summary)

# Generate descriptive statistics for categorical columns, including object type columns
categorical_summary = df.describe(include='object')
print("\nDescriptive statistics for categorical columns:")
display(categorical_summary)
# Out:
# Descriptive statistics for numerical columns:
#                  id  radius_mean  texture_mean  perimeter_mean    area_mean  \
# count  5.690000e+02   569.000000    569.000000      569.000000   569.000000
# mean   3.037183e+07    14.127292     19.289649       91.969033   654.889104
# std    1.250206e+08     3.524049      4.301036       24.298981   351.914129
# min    8.670000e+03     6.981000      9.710000       43.790000   143.500000
# 25%    8.692180e+05    11.700000     16.170000       75.170000   420.300000
# 50%    9.060240e+05    13.370000     18.840000       86.240000   551.100000
# 75%    8.813129e+06    15.780000     21.800000      104.100000   782.700000
# max    9.113205e+08    28.110000     39.280000      188.500000  2501.000000
#
#        smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# count       569.000000        569.000000      569.000000           569.000000
# mean          0.096360          0.104341        0.088799             0.048919
# ...

# %% [markdown]
# ## Visualize data
#
# ### Subtask:
# Create various plots including bar charts, pie charts, line charts, correlation heatmap, and histograms.

# %% [markdown]
# **Reasoning**:
# Create visualizations as requested, including bar chart, pie chart, histograms, and a correlation heatmap. Assess the suitability of line charts for this dataset.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 1. Bar chart for diagnosis counts
plt.figure(figsize=(6, 4))
sns.countplot(x='diagnosis', data=df, palette='viridis')
plt.title('Count of Diagnosis (Malignant vs. Benign)')
plt.xlabel('Diagnosis')
plt.ylabel('Count')
plt.show()

# 2. Pie chart for diagnosis proportions
diagnosis_counts = df['diagnosis'].value_counts()
plt.figure(figsize=(6, 6))
plt.pie(diagnosis_counts, labels=diagnosis_counts.index, autopct='%1.1f%%', colors=['lightcoral', 'lightskyblue'], startangle=90)
plt.title('Proportion of Diagnosis (Malignant vs. Benign)')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# 3. Histograms for a selection of numerical features
numerical_features = ['radius_mean', 'texture_mean', 'perimeter_mean', 'area_mean', 'smoothness_mean']
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_features):
    plt.subplot(2, 3, i + 1)
    sns.histplot(df[col], kde=True, color='skyblue')
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Frequency')
plt.tight_layout()
plt.show()

# 4. Correlation heatmap
# Exclude non-numerical columns like 'id' and 'diagnosis'
numerical_df = df.select_dtypes(include=['float64', 'int64']).drop(columns=['id'])
plt.figure(figsize=(12, 10))
sns.heatmap(numerical_df.corr(), annot=False, cmap='coolwarm')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()

# 5. Assess suitability of line charts
print("\nAssessment of Line Charts:")
print("Line charts are typically used to show trends over time or sequential data.")
print("This dataset contains measurements taken at a single point in time for each patient, not time-series data.")
print("Therefore, line charts are not appropriate for visualizing the relationships or distributions in this dataset.")
# Out:
# /tmp/ipython-input-3584067087.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='diagnosis', data=df, palette='viridis')
# Assessment of Line Charts:
# Line charts are typically used to show trends over time or sequential data.
# This dataset contains measurements taken at a single point in time for each patient, not time-series data.
# Therefore, line charts are not appropriate for visualizing the relationships or distributions in this dataset.

# %% [markdown]
# ## Analyze and interpret
#
# ### Subtask:
# Analyze the visualizations and summary statistics to identify patterns, trends, and outliers.

# %% [markdown]
# **Reasoning**:
# I will now analyze the visualizations and summary statistics to identify patterns, trends, and outliers. I will start by examining the class distribution from the bar and pie charts of the 'diagnosis' column. I will then analyze the distributions of the numerical features using the histograms and summary statistics. Following that, I will interpret the correlation heatmap to understand the relationships between the features. Finally, I will synthesize all this information to identify overall patterns and potential outliers. I will print out my analysis as a structured report.

# %%
# Analysis of Visualizations and Summary Statistics

# 1. Class Distribution Analysis (from Bar and Pie Charts)
print("1. Class Distribution Insights:")
print("The bar chart and pie chart for the 'diagnosis' column show the distribution of malignant (M) and benign (B) cases.")
print(f"Total cases: {len(df)}")
print(f"Benign cases (B): {diagnosis_counts['B']} ({diagnosis_counts['B']/len(df)*100:.1f}%)")
print(f"Malignant cases (M): {diagnosis_counts['M']} ({diagnosis_counts['M']/len(df)*100:.1f}%)")
print("The dataset is somewhat imbalanced, with more benign cases than malignant ones.\n")

# 2. Distribution of Numerical Features (from Histograms and Summary Statistics)
print("2. Numerical Feature Distribution Insights:")
print("The histograms of 'radius_mean', 'perimeter_mean', and 'area_mean' are right-skewed, indicating that most tumors have smaller measurements, with a few larger outliers.")
print("This is also reflected in the summary statistics where the mean is greater than the median for these features.")
print("'texture_mean' and 'smoothness_mean' have distributions that are closer to normal (bell-shaped), though still slightly right-skewed.\n")

# 3. Correlation Analysis (from Heatmap)
print("3. Correlation Insights:")
print("The correlation heatmap reveals strong positive correlations between several features.")
print("For instance, 'radius_mean', 'perimeter_mean', and 'area_mean' are highly correlated, which is expected as they are all measures of tumor size.")
print("There are also strong correlations between 'mean' features and their 'worst' counterparts (e.g., 'radius_mean' and 'radius_worst').")
print("Some features like 'concavity_mean' and 'concave points_mean' also show a strong positive correlation, suggesting a relationship between the severity of concavity and the number of concave points.\n")

# 4. Outlier Analysis (from Histograms and Summary Statistics)
print("4. Outlier Insights:")
print("The right-skewed distributions in features like 'area_mean' and 'perimeter_mean' suggest the presence of outliers on the higher end.")
print("The summary statistics confirm this, with a large difference between the 75th percentile and the maximum values for these features.")
print("For example, for 'area_mean', the 75th percentile is 782.7, while the maximum is 2501.0, indicating potential outliers.\n")

# 5. Synthesis and Overall Patterns
print("5. Overall Patterns and Trends:")
print("The dataset provides a comprehensive set of measurements for breast cancer tumors.")
print("There is a clear distinction in the feature distributions between the two diagnosis classes (although not explicitly plotted in the previous step, it is a key aspect to explore further).")
print("The strong correlations between size-related features suggest that they are largely capturing similar information, which might be important for feature selection in a machine learning model.")
print("The presence of outliers in some features might require special handling, such as scaling or transformation, before building a predictive model.")
# Out:
# 1. Class Distribution Insights:
# The bar chart and pie chart for the 'diagnosis' column show the distribution of malignant (M) and benign (B) cases.
# Total cases: 569
# Benign cases (B): 357 (62.7%)
# Malignant cases (M): 212 (37.3%)
# The dataset is somewhat imbalanced, with more benign cases than malignant ones.
#
# 2. Numerical Feature Distribution Insights:
# The histograms of 'radius_mean', 'perimeter_mean', and 'area_mean' are right-skewed, indicating that most tumors have smaller measurements, with a few larger outliers.
# This is also reflected in the summary statistics where the mean is greater than the median for these features.
# 'texture_mean' and 'smoothness_mean' have distributions that are closer to normal (bell-shaped), though still slightly right-skewed.
#
# 3. Correlation Insights:
# The correlation heatmap reveals strong positive correlations between several features.
# ...

# %% [markdown]
# ## Generate insights
#
# ### Subtask:
# Write 5 key insights based on the data analysis.

# %% [markdown]
# **Reasoning**:
# Based on the analysis performed in the previous steps, I will consolidate the key findings into five concise insights about the dataset.

# %%
# Write 5 key insights based on the data analysis.

print("Key Insights from the Breast Cancer Dataset Analysis:")
print("1. Class Imbalance: The dataset exhibits a class imbalance, with a higher number of benign (B) cases (357) compared to malignant (M) cases (212). This imbalance should be considered when building predictive models.")
print("2. Skewed Distributions: Several numerical features, particularly those related to tumor size such as 'radius_mean', 'perimeter_mean', and 'area_mean', display right-skewed distributions, indicating the presence of tumors with significantly larger measurements than the average.")
print("3. Strong Feature Correlations: There are strong positive correlations among features measuring similar aspects of the tumor, such as size-related features ('radius_mean', 'perimeter_mean', 'area_mean') and between the 'mean' and 'worst' versions of features (e.g., 'radius_mean' and 'radius_worst'). This suggests some redundancy in the features.")
print("4. Potential Outliers: The right-skewed distributions and the significant difference between the 75th percentile and maximum values in features like 'area_mean' indicate the likely presence of outliers, which may need to be addressed during model preprocessing.")
print("5. 'Unnamed: 32' Column: The 'Unnamed: 32' column contained exclusively missing values and was removed during data cleaning, indicating it was an artifact or an empty column in the original data source.")
# Out:
# Key Insights from the Breast Cancer Dataset Analysis:
# 1. Class Imbalance: The dataset exhibits a class imbalance, with a higher number of benign (B) cases (357) compared to malignant (M) cases (212). This imbalance should be considered when building predictive models.
# 2. Skewed Distributions: Several numerical features, particularly those related to tumor size such as 'radius_mean', 'perimeter_mean', and 'area_mean', display right-skewed distributions, indicating the presence of tumors with significantly larger measurements than the average.
# 3. Strong Feature Correlations: There are strong positive correlations among features measuring similar aspects of the tumor, such as size-related features ('radius_mean', 'perimeter_mean', 'area_mean') and between the 'mean' and 'worst' versions of features (e.g., 'radius_mean' and 'radius_worst'). This suggests some redundancy in the features.
# ...

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The dataset contains 569 entries and 33 columns, with one column ('Unnamed: 32') initially containing all missing values.
# *   After removing the 'Unnamed: 32' column, the dataset has 32 columns.
# *   The dataset is somewhat imbalanced in terms of diagnosis, with 357 (62.7%) benign cases and 212 (37.3%) malignant cases.
# *   Numerical features like 'radius\_mean', 'perimeter\_mean', and 'area\_mean' exhibit right-skewed distributions.
# *   There are strong positive correlations between features related to tumor size (e.g., 'radius\_mean', 'perimeter\_mean', 'area\_mean') and between 'mean' and 'worst' versions of the same feature.
# *   Potential outliers are present in features with right-skewed distributions, indicated by the significant difference between the 75th percentile and maximum values.
#
# ### Insights or Next Steps
#
# *   The class imbalance suggests that techniques like oversampling, undersampling, or using appropriate evaluation metrics (e.g., precision, recall, F1-score) should be considered if building a classification model.
# *   The strong correlations between features imply potential multicollinearity, which could be addressed through feature selection or dimensionality reduction techniques like PCA before model training.
